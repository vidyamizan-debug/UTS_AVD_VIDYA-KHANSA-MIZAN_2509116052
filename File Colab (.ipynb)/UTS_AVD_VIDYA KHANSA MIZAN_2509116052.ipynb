# %% [markdown]
# # **WORK FROM HOME EMPLOYEE BURNOUT**

# %% [markdown]
# # **CHECKPOINT 1**

# %% [markdown]
# ## **Import Library**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/AVD/File csv/work_from_home_burnout_dataset.csv'

# %% [markdown]
# ## **Memuat Dataset**

# %%
burn = pd.read_csv(path)
burn
# Out:
#       user_id day_type  work_hours  screen_time_hours  meetings_count  \
# 0           1  Weekday        9.59              11.86               4
# 1           1  Weekend        7.38              10.33               4
# 2           1  Weekend        6.31               8.92               1
# 3           1  Weekday        8.34              10.70               4
# 4           1  Weekend        6.97               9.83               1
# ...       ...      ...         ...                ...             ...
# 1795      180  Weekend        6.33               8.16               0
# 1796      180  Weekend        4.70               7.88               0
# 1797      180  Weekend        3.92               6.39               2
# 1798      180  Weekday        8.93              11.11               2
# 1799      180  Weekend        4.38               6.72               0
#
#       breaks_taken  after_hours_work  sleep_hours  task_completion_rate  \
# ...

# %%
burn.head()
# Out:
#    user_id day_type  work_hours  screen_time_hours  meetings_count  \
# 0        1  Weekday        9.59              11.86               4
# 1        1  Weekend        7.38              10.33               4
# 2        1  Weekend        6.31               8.92               1
# 3        1  Weekday        8.34              10.70               4
# 4        1  Weekend        6.97               9.83               1
#
#    breaks_taken  after_hours_work  sleep_hours  task_completion_rate  \
# 0             2                 0         7.55                  91.2
# 1             1                 0         6.69                  82.0
# 2             2                 0         8.87                  80.6
# 3             1                 1         8.13                  70.0
# 4             2                 0         5.85                  67.1
#
#    burnout_score burnout_risk
# 0          19.17          Low
# 1          29.70          Low
# 2          32.93          Low
# ...

# %%
burn.tail()
# Out:
#       user_id day_type  work_hours  screen_time_hours  meetings_count  \
# 1795      180  Weekend        6.33               8.16               0
# 1796      180  Weekend        4.70               7.88               0
# 1797      180  Weekend        3.92               6.39               2
# 1798      180  Weekday        8.93              11.11               2
# 1799      180  Weekend        4.38               6.72               0
#
#       breaks_taken  after_hours_work  sleep_hours  task_completion_rate  \
# 1795             4                 0         5.59                  73.5
# 1796             4                 0         6.69                  89.8
# 1797             1                 0         6.77                  74.6
# 1798             5                 0         8.28                  74.6
# 1799             1                 0         7.13                  70.7
#
#       burnout_score burnout_risk
# 1795          31.91          Low
# 1796          26.30          Low
# ...

# %% [markdown]
# ## **Business Understanding**

# %% [markdown]
# ## **Business Objective**

# %% [markdown]
# Dataset Work From Home Employee Burnout
#
# Data ini merupakan sebuah kumpulan data yang memuat kondisi karyawan selama melakukan Work From Home atau yang disingkat sebagai WFH. Ini digunakan agar kita dapat memahami faktor apa saja yang memengaruhi tingkat burnout, seperti jam kerja dan istirahat, serta work life balance.
#
# Dalam dataset ini terdapat 1800 baris dan 11 kolom

# %% [markdown]
# ## **Assess Situation**

# %% [markdown]
# Burnout ini sering menjadi isu bagi para karyawan yang menerapkan situasi WFH di pola kerjanya. Adanya perubahan pola kerja ini dapat memengaruhi tingkat stres yang dimiliki karyawan. Oleh karena itu, perusahaan perlu untuk melakukan analisis seperti dataset ini untuk bisa memahami penyebab burnout yang dialami oleh karyawan mereka.

# %% [markdown]
# ## **Analytic Goals Project Plan**

# %% [markdown]
# Dalam dataset ini akan dilakukan:
#
#
# *   Mengidentifikasi faktor yang menyebabkan burnout pada karyawan.
# *   Menganalisis hubungan antar faktor dengan tingkat stres yang dimiliki karyawan.
#
#
# *   Menghasilkan visualisasi.
# *   Memberikan dasar rekomendasi keputusan.

# %% [markdown]
# # **CHECKPOINT 2**

# %% [markdown]
# ## **Data Understanding**

# %% [markdown]
# ### **Struktur Data (Informasi Lanjutan)**

# %%
burn.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1800 entries, 0 to 1799
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   user_id               1800 non-null   int64
#  1   day_type              1800 non-null   object
#  2   work_hours            1800 non-null   float64
#  3   screen_time_hours     1800 non-null   float64
#  4   meetings_count        1800 non-null   int64
#  5   breaks_taken          1800 non-null   int64
#  6   after_hours_work      1800 non-null   int64
#  7   sleep_hours           1800 non-null   float64
#  8   task_completion_rate  1800 non-null   float64
#  9   burnout_score         1800 non-null   float64
#  10  burnout_risk          1800 non-null   object
# dtypes: float64(5), int64(4), object(2)
# memory usage: 154.8+ KB

# %% [markdown]
# 1. **user_id**:\
#         Jumlah baris: 1800\
#         Tipe data: int64\
#         Deskripsi: ID Pengguna
#
# 2. **day_type**:\
#         Jumlah baris: 1800\
#         Tipe data: object\
#         Deskripsi: Tipe Hari
#
# 3. **work_hours**:\
#         Jumlah baris: 1800\
#         Tipe data: float64\
#         Deskripsi: Jam Kerja
#
# 4. **screen_time_hours**:\
#         Jumlah baris: 1800\
#         Tipe data: float64\
#         Deskripsi: Jam Screen Time
#
# 5. **meetings_count**:\
#         Jumlah baris: 1800\
#         Tipe data: int64\
#         Deskripsi: Jumlah Meetings
#
# 6. **breaks_taken**:\
#         Jumlah baris: 1800\
#         Tipe data: int64\
#         Deskripsi: Jam Istirahat yang diambil
#
# 7. **after_hours_work**:\
#         Jumlah baris: 1800\
#         Tipe data: int64\
#         Deskripsi: Jam Lembur
#
# 8. **sleep_hours**:\
#         Jumlah baris: 1800\
#         Tipe data: float64\
#         Deskripsi: Jam Tidur
#
# 9. **task_completion_rate**:\
#         Jumlah baris: 1800\
#         Tipe data: float64\
#         Deskripsi: Tingkat Keberhasilan Tugas
#
# 10. **burnout_score**:\
#         Jumlah baris: 1800\
#         Tipe data: float64\
#         Deskripsi: Nilai Stress (burnout)
#
# 11. **burnout_risk**:\
#         Jumlah baris: 1800\
#         Tipe data: object\
#         Deskripsi: Risiko Stress (burnout)

# %% [markdown]
# ### **Statistik Deskriptif**

# %%
burn.describe()
# Out:
#            user_id   work_hours  screen_time_hours  meetings_count  \
# count  1800.000000  1800.000000        1800.000000     1800.000000
# mean     90.500000     6.515117           9.271406        1.941111
# std      51.975162     2.290521           2.409253        1.696178
# min       1.000000     3.000000           4.510000        0.000000
# 25%      45.750000     4.430000           7.240000        1.000000
# 50%      90.500000     6.445000           9.210000        2.000000
# 75%     135.250000     8.510000          11.310000        3.000000
# max     180.000000    12.170000          15.700000       10.000000
#
#        breaks_taken  after_hours_work  sleep_hours  task_completion_rate  \
# count   1800.000000       1800.000000  1800.000000           1800.000000
# mean       3.028889          0.358889     6.996467             72.308556
# std        1.417844          0.479808     1.061740             14.978647
# ...

# %%
burn.describe(include='all')
# Out:
#             user_id day_type   work_hours  screen_time_hours  meetings_count  \
# count   1800.000000     1800  1800.000000        1800.000000     1800.000000
# unique          NaN        2          NaN                NaN             NaN
# top             NaN  Weekend          NaN                NaN             NaN
# freq            NaN      924          NaN                NaN             NaN
# mean      90.500000      NaN     6.515117           9.271406        1.941111
# std       51.975162      NaN     2.290521           2.409253        1.696178
# min        1.000000      NaN     3.000000           4.510000        0.000000
# 25%       45.750000      NaN     4.430000           7.240000        1.000000
# 50%       90.500000      NaN     6.445000           9.210000        2.000000
# 75%      135.250000      NaN     8.510000          11.310000        3.000000
# max      180.000000      NaN    12.170000          15.700000       10.000000
#
# ...

# %% [markdown]
# 1. **Count** (Kelengkapan Data)\
# Berdasarkan data, total baris adalah 1800 baris dan seluruh kolom memiliki count sebanyak 1800, sehingga pada dataset ini tidak terdapat Missing Values.
#
# Kesimpulan:\
# Dataset bersifat lengkap dan tidak memiliki Missing Values.
#
# ---
#
# 2. **Mean vs Median** (Distribusi Data)
#
# * Sebagian besar variabel yang diperoleh disini seperti pada work_hours, screen_time_hours, meetings_count, breaks_taken, dan sleep_hours memiliki mean dan median yang bisa dibilang cukup berdekatan. Yang artinya, distribusi datanya disini relatif simetris.
#
# * Namun, mean dan median untuk data burnout_score dan task_completion_rate cukup berbeda antar satu sama lain. Hal ini menunjukkan bahwa distribusi datanya lebih condong ke tipe distribusi skewed left-right.
#
#
# Kesimpulan:\
# Secara keseluruhan, kebanyakan variabel memiliki distribusi data yang normal atau relatif simetris. Namun ada juga beberapa data yang bersifat skewed (baik ke kiri dan kanan), di mana terdapat nilai-nilai ekstrem tinggi yang memengaruhi nilai rata-rata di semua variabel utama.
#
# ---
#
# 3. **Min dan Max** (Validasi Logika)
#
# * user_id
#   * Min = 1.00
#   * Max = 180.00
#
# * work_hours
#   * Min = 3.00
#   * Max = 12.17
#
# * screen_time_hours
#   * Min = 4.51
#   * Max = 15.70
#
# * meetings_count
#   * Min = 0.00
#   * Max = 10.00
#
# * breaks_taken
#   * Min = 1.00
#   * Max = 5.00
#
# * after_hours_work
#   * Min = 0.00
#   * Max = 1.00
#
# * sleep_hours
#   * Min = 4.50
#   * Max = 10.80
#
# * task_completion_rate
#   * Min = 40.00
#   * Max = 107.20
#
# * burnout_score
#   * Min = 2.50
#   * Max = 143.92
#
# Kesimpulan:
# * Secara umum, nilai minimum dan maksimum pada seluruh variabel masih realistis. Dimana jam kerja (3–12 jam), screen time (4–15 jam), jumlah meeting (0–10), serta waktu tidur (4.5–10.8 jam) masih masuk akal dalam konteks aktivitas harian.
#
# * Namun ada beberapa variabel yang perlu diperhatikan jam nya, seperti task_completion_rate yang melebihi 100% (107.20) dan burnout_score yang cukup tinggi (143.92). Nilai-nilai ini berpotensi menjadi outlier atau menunjukkan kondisi ekstrem pada sebagian individu.
#
# ---
#
# 4. **Standar Deviasi** (std) - Variabilitas Data
#
# * user_id
#   * Mean = 90.50
#   * Std = 51.97
#
# * work_hours
#   * Mean = 6.51
#   * Std = 2.29
#
# * screen_time_hours
#   * Mean = 9.27
#   * Std = 2.40
#
# * meetings_count
#   * Mean = 1.94
#   * Std = 1.69
#
# * breaks_taken
#   * Mean = 3.02
#   * Std = 1.41
#
# * after_hours_work
#   * Mean = 0.35
#   * Std = 0.47
#
# * sleep_hours
#   * Mean = 6.99
#   * Std = 1.06
#
# * task_completion_rate
#   * Mean = 72.30
#   * Std = 14.97
#
# * burnout_score
#   * Mean = 44.00
#   * Std = 23.88
#
# Kesimpulan:
#
# * Variasi terbesar terlihat pada burnout_score (Std = 23.88) dan task_completion_rate (Std = 14.97), yang menunjukkan adanya perbedaan tingkat burnout dan performa kerja yang cukup besar antar individu.
#
# * Sementara itu, variabel seperti sleep_hours (Std = 1.06) dan after_hours_work (Std = 0.47) memiliki variasi yang lebih kecil, sehingga datanya relatif lebih stabil.

# %% [markdown]
# ### **Data Types Check**

# %%
burn.dtypes
# Out:
# user_id                   int64
# day_type                 object
# work_hours              float64
# screen_time_hours       float64
# meetings_count            int64
# breaks_taken              int64
# after_hours_work          int64
# sleep_hours             float64
# task_completion_rate    float64
# burnout_score           float64
# burnout_risk             object
# dtype: object

# %% [markdown]
# **Kesimpulan :**
#
# * Variabel numerik seperti work_hours, screen_time_hours, sleep_hours, task_completion_rate, dan burnout_score memiliki tipe **float64**, yang tepat karena mengandung nilai desimal.
#
# * Variabel seperti meetings_count, breaks_taken, dan after_hours_work bertipe **int64**, sesuai karena berupa angka bulat. Adapun user_id yang juga bertipe **int64**, namun berfungsi sebagai identitas unik sehingga tidak digunakan dalam analisis statistik.
#
# * Kolom day_type dan burnout_risk bertipe **object**, yang menunjukkan bahwa keduanya merupakan data kategorikal.

# %% [markdown]
# ### **Inconsistent Values**

# %% [markdown]
# **1. day_type**

# %%
print(burn['day_type'].unique())
# Out:
# ['Weekday' 'Weekend']

# %% [markdown]
# **2. burnout_risk**

# %%
print(burn['burnout_risk'].unique())
# Out:
# ['Low' 'Medium' 'High']

# %% [markdown]
# **Kesimpulan :**
#
#
# *   Tidak ditemukan data yang inkonsisten pada variabel day_type dan burnout_risk.

# %% [markdown]
# ### **Missing Values**

# %%
pd.DataFrame(burn.isna().sum() / len(burn) * 100, columns=['Null Ratio in %'])
# Out:
#                       Null Ratio in %
# user_id                           0.0
# day_type                          0.0
# work_hours                        0.0
# screen_time_hours                 0.0
# meetings_count                    0.0
# breaks_taken                      0.0
# after_hours_work                  0.0
# sleep_hours                       0.0
# task_completion_rate              0.0
# burnout_score                     0.0
# burnout_risk                      0.0

# %% [markdown]
# **Kesimpulan :**
#
# *   Semua kolom memiliki nilai Missing Values sebesar 0%, yang artinya tidak ada data yang kosong di dalam dataset ini.

# %% [markdown]
# ### **Duplicated Values**

# %%
burn[burn.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, day_type, work_hours, screen_time_hours, meetings_count, breaks_taken, after_hours_work, sleep_hours, task_completion_rate, burnout_score, burnout_risk]
# Index: []

# %% [markdown]
# **Kesimpulan :**
#
# *   Tidak ada Duplicated Values pada dataset ini.

# %% [markdown]
# ### **Outliers**

# %%
results = []

cols = burn.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = burn[col].quantile(0.25)
  q3 = burn[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = burn[(burn[col] < lower_bound) | (burn[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(burn))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_burn = pd.DataFrame(results)
results_burn.set_index('Kolom', inplace=True)
results_df = results_burn.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_burn)
# Out:
#                       Persentase Outliers
# Kolom
# user_id                          0.000000
# work_hours                       0.000000
# screen_time_hours                0.000000
# meetings_count                   1.555556
# breaks_taken                     0.000000
# after_hours_work                 0.000000
# sleep_hours                      0.277778
# task_completion_rate             0.000000
# burnout_score                    1.277778

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=burn['meetings_count'])
plt.title('Boxplot of Meetings Count')
plt.ylabel('Meetings Count')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=burn['burnout_score'])
plt.title('Boxplot of Burnout Score')
plt.ylabel('Burnout Score')
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(y=burn['sleep_hours'])
plt.title('Boxplot of Sleep Hours')
plt.ylabel('Sleep Hours')
plt.show()

# %% [markdown]
# **Kesimpulan :**
#
#
# *  Terdapat beberapa Outliers pada meetings_count (1.56%), burnout_score (1.28%), dan sleep_hours (0.28%).
#
# *  Menurut saya, dengan adanya outliers yang jumlahnya bisa dibilang kecil ini tidak terlalu mengganggu analisis dataset ini.

# %% [markdown]
# ## **Eksplorasi Data (EDA)**

# %% [markdown]
# ### **Comparison/Perbandingan**

# %%
avg_burnout_by_day_type = burn.groupby('day_type')['burnout_score'].mean().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=avg_burnout_by_day_type.index, y=avg_burnout_by_day_type.values, palette='viridis', hue=avg_burnout_by_day_type.index, legend=False)
plt.title('Average Burnout Score by Day Type')
plt.xlabel('Day Type')
plt.ylabel('Average Burnout Score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Kesimpulan :**
#
#
# *   Rata-rata burnout score lebih tinggi pada Weekday dibandingkan Weekend. Ini menunjukkan bahwa tingkat kelelahan atau stres cenderung meningkat saat hari kerja dibandingkan akhir pekan.

# %% [markdown]
# ### **Composition/Komposisi**

# %%
burnout_risk_counts = burn['burnout_risk'].value_counts()

plt.figure(figsize=(10, 8))
plt.pie(burnout_risk_counts, labels=burnout_risk_counts.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proporsi Karyawan Berdasarkan Risiko Burnout')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# **Kesimpulan :**
#
#
# *   Mayoritas karyawan berada pada kategori risiko burnout rendah (84.8%), sementara risiko sedang 14.1% dan tinggi hanya 1.1%. Ini menunjukkan secara umum kondisi masih terkendali, tetapi tetap perlu perhatian pada kelompok risiko sedang dan tinggi agar tidak meningkat.

# %% [markdown]
# ### **Distribution/Distribusi**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(burn['work_hours'], bins=20, kde=True)
plt.title('Distribusi Jam Kerja')
plt.xlabel('Jam Kerja')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# **Kesimpulan :**
#
# * Distribusi pada tabel menunjukkan bahwa distribusinya ini condong ke skewed left.
#
# *   Distribusi jam kerja terlihat menyebar antara sekitar 3 hingga 12 jam, dengan konsentrasi terbesar berada di kisaran 4–6 jam dan 8–9 jam. Ini menunjukkan adanya dua pola jam kerja dominan, kemungkinan mencerminkan perbedaan beban kerja antar karyawan atau tipe hari kerja.

# %% [markdown]
# ### **Relationship/Hubungan**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=burn[['work_hours', 'burnout_score']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi antara Jam Kerja dan Tingkat Stress')
plt.show()

# %% [markdown]
# **Kesimpulan :**
#
#
# *   Nilai korelasi sebesar 0.12 menunjukkan bahwa hubungan antara jam kerja dan tingkat stres sangat lemah dan hampir tidak signifikan. Artinya, peningkatan jam kerja tidak secara langsung berkaitan kuat dengan kenaikan burnout dalam data ini.

# %% [markdown]
# ## **Menyimpan File to csv**

# %%
burn.to_csv('WorkFromHomeEmployeeBurnout.csv', index=False)

# %% [markdown]
# # **CHECKPOINT 3**

# %% [markdown]
# ## **Data Preparation**

# %% [markdown]
# ## **Data Type**

# %% [markdown]
# ### **Inconsistent Values**

# %% [markdown]
# Berdasarkan hasil pengecekan inconsistent values pada bagian CheckPoint 2, bisa dilihat bahwa pada dataset ini tidak terdapat data yang tertulis secara inkonsisten. berikut ialah data yang saya cek saat CheckPoint 2 :

# %% [markdown]
# 1. **day_type**

# %%
print(burn['day_type'].unique())
# Out:
# ['Weekday' 'Weekend']

# %% [markdown]
# 2. **burnout_risk**

# %%
print(burn['burnout_risk'].unique())
# Out:
# ['Low' 'Medium' 'High']

# %% [markdown]
# Dan bisa dilihat kembali pada dua poin di atas, bahwa tidak terdapat inconsistent values pada kolom yang bertipe data 'object'. Semua penulisan tertulis secara konsisten.

# %% [markdown]
# ### **Missing Values**

# %% [markdown]
# Disini saya akan melakukan pengecekan kembali pada dataset, untuk mengecek apakah ada data yang hilang atau missing value

# %%
pd.DataFrame(burn.isna().sum() / len(burn) * 100, columns=['Null Ratio in %'])
# Out:
#                       Null Ratio in %
# user_id                           0.0
# day_type                          0.0
# work_hours                        0.0
# screen_time_hours                 0.0
# meetings_count                    0.0
# breaks_taken                      0.0
# after_hours_work                  0.0
# sleep_hours                       0.0
# task_completion_rate              0.0
# burnout_score                     0.0
# burnout_risk                      0.0

# %% [markdown]
# Bisa dilihat dari persentasenya bahwa dataset ini tidak memiliki missing values. Karena semua kolom memiliki persentase sebesar 0%.

# %% [markdown]
# ### **Duplicated Values**

# %% [markdown]
# Saya akan melakukan pengecekan kembali terhadap dataset, apakah ada data yang terduplikat atau duplicated values atau tidak.

# %%
burn[burn.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, day_type, work_hours, screen_time_hours, meetings_count, breaks_taken, after_hours_work, sleep_hours, task_completion_rate, burnout_score, burnout_risk]
# Index: []

# %% [markdown]
# Dapat dilihat bahwa tidak terdapat data ataupun baris data yang terduplikat di dalam dataset milik saya ini.

# %% [markdown]
# ### **Outliers Values**

# %% [markdown]
# Disini saya akan melakukan pengecekan kembali terhadap dataset saya, agar saya dapat melihat apakah terdapat data anomali atau ouliers di data saya.

# %%
results = []

cols = burn.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = burn[col].quantile(0.25)
  q3 = burn[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = burn[(burn[col] < lower_bound) | (burn[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(burn))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_burn = pd.DataFrame(results)
results_burn.set_index('Kolom', inplace=True)
results_df = results_burn.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_burn)
# Out:
#                       Persentase Outliers
# Kolom
# user_id                          0.000000
# work_hours                       0.000000
# screen_time_hours                0.000000
# meetings_count                   1.555556
# breaks_taken                     0.000000
# after_hours_work                 0.000000
# sleep_hours                      0.277778
# task_completion_rate             0.000000
# burnout_score                    1.277778

# %% [markdown]
# Berdasarkan tabel pengecekan ouliers di atas, bisa dilihat bahwa terdapat outliers pada kolom meetings_count, sleep_hours, dan burnout_score. Namun menurut saya, tidak diperlukannya penanganan outliers pada ketiga kolom tersebut. Karena jumlah persentasenya yang masih bisa tergolong kecil dan tidak mempengaruhi data secara signifikan. Berikut adalah penjelasan lebih lanjut untuk ketiga kolom yang memiliki outliers :

# %% [markdown]
# 1. **meetings_count**\
# Kolom meetings_count memiliki outlier sebesar 1.56%. Persentase ini masih dikatakan tergolong kecil karena berada di bawah 5%. Selain itu, jumlah rapat yang banyak masih bisa terjadi pada beberapa pekerjaan tertentu, sehingga nilai tersebut masih dianggap wajar. Oleh karena itu, menurut saya tidak perlu untuk melakukan penanganan outliers.

# %% [markdown]
# 2.  **sleep_hours**\
# Kolom sleep_hours memiliki outlier sebesar 0.28%. Jumlah ini terbilang sangat kecil sehingga tidak terlalu mempengaruhi data secara keseluruhan. Selain itu, setiap orang juga pastinya memiliki jam tidur yang berbeda-beda, sehingga nilai yang berbeda jauh masih bisa dianggap normal. Oleh karena itu, menurut saya tidak diperlukan penanganan untuk mengatasi outliers pada kolom ini.

# %% [markdown]
# 3. **burnout_score**\
# Kolom burnout_score memiliki outlier sebesar 1.28%. Persentase ini juga masih terbilang kecil dan tidak terlalu mempengaruhi distribusi data secara keseluruhan. Perbedaan tingkat burnout pada setiap orang juga merupakan hal yang wajar karena dipengaruhi oleh kondisi kerja dan faktor lainnya. Oleh karena itu, menurut saya tidak perlu penanganan outliers disini.

# %% [markdown]
# ## **Data Construction**

# %% [markdown]
# **Alasan :**
#
# Pada tahap data construction ini saya akan menambahkan satu kolom baru yaitu kolom work_load, kolom ini berguna untuk membantu kita dalam melihat apakah pekerja dengan jam kerja yang lebih tinggi memiliki kecenderungan untuk memiliki tingkat burnout yang lebih besar

# %%
def categorize_workload(work_hours):
    if work_hours > 9:
        return 'High'
    elif work_hours >= 7:
        return 'Medium'
    else:
        return 'Low'

burn['work_load'] = burn['work_hours'].apply(categorize_workload)

# %% [markdown]
# Selanjutnya, saya akan mengecek apakah kolom yang baru saja saya buat ini berhasil ditambahkan ke dataset atau tidak.

# %%
print(burn.columns)
# Out:
# Index(['user_id', 'day_type', 'work_hours', 'screen_time_hours',
#        'meetings_count', 'breaks_taken', 'after_hours_work', 'sleep_hours',
#        'task_completion_rate', 'burnout_score', 'burnout_risk', 'work_load'],
#       dtype='object')

# %% [markdown]
# Seperti yang bisa dilihat, kolom 'work_load' berhasil untuk ditambahkan ke  dataset.

# %% [markdown]
# ## **Data Reduction**

# %% [markdown]
# **Alasan :**
#
# Pada tahap data reduction ini, saya akan menghapus kolom 'user_id', hal ini dikarenakan kolom tersebut hanya berfungsi sebagai identitas unik setiap pengguna dan tidak memiliki pengaruh langsung terhadap proses analisis data.

# %%
burn = burn.drop('user_id', axis=1)

# %% [markdown]
# Selanjutnya, saya akan mengecek apakah kolom yang baru saja saya hapus ini berhasil terhapus dari dataset atau tidak.

# %%
print(burn.columns)
# Out:
# Index(['day_type', 'work_hours', 'screen_time_hours', 'meetings_count',
#        'breaks_taken', 'after_hours_work', 'sleep_hours',
#        'task_completion_rate', 'burnout_score', 'burnout_risk', 'work_load'],
#       dtype='object')

# %% [markdown]
# Seperti yang bisa dilihat, kolom 'user_id' berhasil untuk dihapus dari dataset.

# %% [markdown]
# ## **Menyimpan Dataset (Bersih)**

# %%
burn.to_csv('[Bersih]WorkFromHomeEmployeeBurnout.csv', index=False)

# %% [markdown]
# # **CHECKPOINT 4**

# %% [markdown]
# ## **Memuat Dataset [Bersih]**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path = '/content/[Bersih]WorkFromHomeEmployeeBurnout.csv'

# %%
burn_clean = pd.read_csv(path)
burn_clean
# Out:
#      day_type  work_hours  screen_time_hours  meetings_count  breaks_taken  \
# 0     Weekday        9.59              11.86               4             2
# 1     Weekend        7.38              10.33               4             1
# 2     Weekend        6.31               8.92               1             2
# 3     Weekday        8.34              10.70               4             1
# 4     Weekend        6.97               9.83               1             2
# ...       ...         ...                ...             ...           ...
# 1795  Weekend        6.33               8.16               0             4
# 1796  Weekend        4.70               7.88               0             4
# 1797  Weekend        3.92               6.39               2             1
# 1798  Weekday        8.93              11.11               2             5
# 1799  Weekend        4.38               6.72               0             1
#
# ...

# %% [markdown]
# ## **Visualisasi Data**

# %% [markdown]
# ### **Bar Chart**

# %% [markdown]
# Berikut ini ialah Bar Chart yang saya buat dan gunakan untuk bisa melihat beban kerja dari karyawan WFH yang sudah di kategorikan menjadi 'Low', 'Medium', dan 'High'. Hal ini memungkinkan kita untuk dapat melihat berapa banyak karyawan WFH yang tergolong memiliki beban kerja 'High', 'Medium', maupun 'Low'.

# %%
beban_kerja= burn_clean['work_load'].value_counts().head(3).sort_values(ascending=False)

plt.figure(figsize=(10, 6))
plt.bar(beban_kerja.index, beban_kerja.values, color='lightcoral')
plt.xlabel('Beban Kerja yang Dimiliki Karyawan')
plt.ylabel('Jumlah Karyawan')
plt.title('Klasifikasi Beban Kerja Karyawan')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight :**
#
#
# * Sebagian besar karyawan WFH berada pada kategori beban kerja rendah (Low) dibandingkan kategori Medium dan High. Hal ini menunjukkan bahwa mayoritas karyawan tidak mengalami tekanan kerja yang terlalu tinggi saat bekerja dari rumah.
#
# * Jumlah karyawan dengan beban kerja sedang (Medium) berada di posisi kedua setelah kategori Low. Hal ini menunjukkan bahwa sebagian karyawan masih memiliki beban kerja yang cukup signifikan.
#
# * Jumlah karyawan dengan beban kerja tinggi (High) merupakan yang paling sedikit dibandingkan kategori lainnya. Walaupun jumlahnya kecil, kelompok ini berpotensi mengalami kelelahan atau burnout.
#
#
# **Action :**
#
#
# * Perusahaan dapat mempertahankan sistem kerja yang ada saat ini karena beban kerja sebagian besar karyawan masih dalam tingkat yang wajar dan tidak terlalu berat.
#
# * Perusahaan dapat melakukan pemantauan beban kerja secara berkala agar karyawan pada kategori Medium tidak mengalami peningkatan beban kerja yang berlebihan.
#
# * Perusahaan dapat memberikan dukungan tambahan, seperti pengaturan ulang tugas, manajemen waktu kerja yang lebih baik, atau pemberian waktu istirahat yang cukup bagi karyawan dengan beban kerja tinggi.

# %% [markdown]
# ### **Pie Chart**

# %% [markdown]
# Berikut ini ialah Pie Chart yang saya buat dan gunakan untuk dapat melihat berapa persentase dari risiko burnout yang dimiliki oleh karyawan yang bekerja WFH.

# %%
plt.figure(figsize=(10, 6))
plt.pie(burn_clean['burnout_risk'].value_counts(), labels=burn_clean['burnout_risk'].value_counts().index, autopct='%1.1f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold']) # colors (warna)
plt.title('Distribusi Risiko Burnout')
plt.show()

# %% [markdown]
# **Insight :**
#
#
# * Sebagian besar karyawan WFH memiliki risiko burnout yang rendah (Low) dengan persentase sekitar 84.8%. Hal ini menunjukkan bahwa mayoritas karyawan masih mampu mengelola pekerjaan dan tekanan kerja dengan cukup baik.
#
# * Sebanyak 14.1% karyawan berada pada tingkat risiko burnout sedang (Medium). Kelompok ini memiliki potensi mengalami peningkatan stres kerja apabila beban kerja tidak dikelola dengan baik.
#
# * Hanya sekitar 1.1% karyawan yang berada pada risiko burnout tinggi (High). Meskipun jumlahnya kecil, kelompok ini tetap perlu diperhatikan karena berpotensi mengalami kelelahan kerja yang serius.
#
#
# **Action :**
#
#
# * Perusahaan dapat mempertahankan sistem kerja WFH yang ada, karena sebagian besar karyawan masih berada pada tingkat risiko burnout yang rendah.
#
# * Perusahaan dapat melakukan monitoring atau evaluasi secara berkala terhadap karyawan dengan risiko burnout sedang, agar tidak meningkat menjadi risiko yang lebih tinggi.
#
# * Bagi karyawan dengan risiko burnout tinggi, perusahaan dapat memberikan dukungan seperti pengurangan beban kerja, manajemen waktu kerja yang lebih baik, atau program kesejahteraan karyawan untuk membantu mengurangi stres kerja.

# %% [markdown]
# ### **Line Chart**

# %% [markdown]
# Menurut saya, pada dataset 'Work From Home Employee Burnout' ini tidak diperlukannya untuk membuat sebuah line chart. Hal ini dikarenakan fungsi utama dari line chart sendiri ialah untuk melihat tren atau perubahan nilai dari waktu ke waktu, ini biasanya menggunakan sebuah kolom yang memuat data berupa tanggal. Namun, pada dataset saya tidak terdapat kolom yang mengandung unsur tanggal di dalamnya.

# %% [markdown]
# ### **Histogram**

# %% [markdown]
# Berikut ini ialah histogram yang saya buat dan gunakan untuk membantu saya untuk melihat distribusi data yang bersifat numerik dan pola penyebarannya seperti apa. Disini saya ingin melihat distribusi dan pola penyebaran data oleh kolom 'burnout_score' dan seperti yang bisa dilihat di bawah persebaran datanya ialah skewed right, yang artinya histogramnya lebih condong ke sebelah kanan.

# %%
plt.figure(figsize=(8, 5))
sns.histplot(burn_clean['burnout_score'], bins=20, kde=True, color='lightcoral')
plt.title('Distribusi Risiko Burnout')
plt.xlabel('Risiko Burnout')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# **Insight :**
#
#
# * Histogram menunjukkan bahwa sebagian besar nilai burnout_score berada pada rentang rendah hingga menengah. Hal ini menandakan bahwa mayoritas karyawan tidak mengalami tingkat burnout yang terlalu tinggi.
#
# * Distribusi data terlihat skewed ke kanan (right-skewed), yang berarti hanya sebagian kecil karyawan yang memiliki nilai burnout_score yang sangat tinggi dibandingkan mayoritas lainnya.
#
# * Adanya beberapa nilai burnout yang tinggi menunjukkan bahwa masih ada sebagian kecil karyawan yang berpotensi mengalami kelelahan kerja yang cukup serius.
#
#
# **Action :**
#
#
# * Perusahaan dapat mempertahankan kebijakan kerja yang ada, karena sebagian besar karyawan masih berada pada tingkat burnout yang relatif rendah hingga sedang.
#
# * Perusahaan perlu melakukan pemantauan terhadap karyawan dengan nilai burnout yang tinggi, misalnya dengan evaluasi beban kerja atau pemberian dukungan kesehatan mental.
#
# * Program seperti manajemen stres, pengaturan waktu kerja yang lebih fleksibel, atau peningkatan waktu istirahat dapat diterapkan untuk membantu mengurangi risiko burnout pada karyawan.

# %% [markdown]
# ### **BoxPlot**

# %% [markdown]
# Berikut ini ialah BoxPlot yang saya buat dan gunakan untuk melihat distribusi skor burnout karyawan yang bekerja dari rumah (WFH) berdasarkan tingkat beban kerja (work_load) yang paling sering muncul, yaitu Low, Medium, dan High.

# %%
top3skor = burn_clean['work_load'].value_counts().head(3).index
burn_top3skor = burn_clean[burn_clean['work_load'].isin(top3skor)]

plt.figure(figsize=(12, 7))
burn_top3skor.boxplot(column='burnout_score', by='work_load', ax=plt.gca(), grid=False, patch_artist=True, medianprops=dict(color='lightcoral'))
plt.title('TOP 3 SKOR BURN OUT PADA KARYAWAN WFH', fontsize=16)
plt.xlabel('BEBAN KERJA', fontsize=12)
plt.ylabel('SKOR BURNOUT', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.suptitle('')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight :**
#
#
# * Ketiga kategori beban kerja menunjukkan distribusi skor burnout yang cukup bervariasi, namun kategori High dan Medium cenderung memiliki median burnout yang sedikit lebih tinggi dibandingkan Low.
#
# * Terdapat beberapa outlier dengan skor burnout yang sangat tinggi, yang menunjukkan bahwa sebagian karyawan mengalami tingkat kelelahan kerja yang jauh di atas rata-rata.
#
# * Penyebaran data yang cukup lebar pada setiap kategori menunjukkan bahwa burnout tidak hanya dipengaruhi oleh beban kerja saja, tetapi kemungkinan juga oleh faktor lain.
#
#
# **Action :**
#
#
# * Perusahaan dapat melakukan monitoring lebih lanjut pada karyawan dengan beban kerja tinggi atau yang memiliki skor burnout ekstrem.
#
# * Perlu adanya pengelolaan beban kerja yang lebih seimbang agar tidak memicu peningkatan burnout pada karyawan.
#
# * Program seperti manajemen stres, evaluasi distribusi tugas, dan dukungan kesehatan mental dapat membantu mengurangi risiko burnout pada karyawan WFH.

# %% [markdown]
# ### **Bubble Chart**

# %% [markdown]
# Menurut saya, pada dataset 'Work From Home Employee Burnout' ini tidak diperlukan penggunaan bubble chart. Hal ini karena bubble chart biasanya digunakan untuk menampilkan hubungan antara tiga variabel sekaligus, yaitu dua variabel pada sumbu X dan Y serta satu variabel tambahan yang ditampilkan melalui ukuran gelembung (bubble). Sementara itu, pada analisis yang saya lakukan sudah cukup jelas ditampilkan menggunakan visualisasi seperti scatter plot atau heatmap untuk melihat hubungan antar variabel. Jika menggunakan bubble chart, visualisasi justru bisa menjadi lebih sulit dibaca dan kurang efektif, terutama jika ukuran bubble saling tumpang tindih sehingga informasi yang ingin disampaikan menjadi kurang jelas.

# %% [markdown]
# ### **ScatterPlot**

# %% [markdown]
# Berikut ini ialah Scatter Plot yang saya buat dan gunakan untuk melihat hubungan antara work_hours (jumlah jam kerja) pada sumbu X dan sleep_hours (jumlah jam tidur) pada sumbu Y. Setiap titik pada grafik mewakili satu data orang. Dari grafik terlihat bahwa titik-titik tersebar cukup acak, sehingga tidak terlihat hubungan yang sangat kuat antara jam kerja dan jam tidur. Namun, sebagian besar orang tetap memiliki waktu tidur sekitar 6–8 jam meskipun jam kerja mereka berbeda-beda. Grafik ini membantu kita melihat apakah ada pola antara lama bekerja dan lama tidur.

# %%
plt.figure(figsize=(10, 6))
plt.scatter(burn_clean['work_hours'], burn_clean['sleep_hours'], alpha=0.7, color='lightcoral')
plt.title('Korelasi Jam Kerja dan Jam Tidur', fontsize=16)
plt.xlabel('Jam Kerja', fontsize=12)
plt.ylabel('Jam Tidur', fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# **Insight :**
#
#
# * Sebagian besar data berada pada jam kerja sekitar 3–10 jam dengan waktu tidur sekitar 6–8 jam.
#
# * Titik-titik data tersebar cukup merata, sehingga hubungan antara jam kerja dan jam tidur tidak terlalu kuat.
#
# * Ada beberapa data yang menunjukkan jam kerja tinggi tetapi waktu tidurnya tetap cukup.
#
#
# **Action :**
#
#
# * Melakukan analisis lanjutan seperti menghitung korelasi untuk mengetahui apakah kedua variabel benar-benar saling berhubungan.
#
# * Menambahkan kategori lain (misalnya umur atau pekerjaan) untuk melihat apakah ada pola yang lebih jelas.

# %% [markdown]
# ### **Heatmap**

# %% [markdown]
# Berikut ini ialah Heatmap yang saya buat dan gunakan untuk melihat hubungan atau korelasi antara beberapa variabel, yaitu work_hours (jam kerja), sleep_hours (jam tidur), screen_time_hours (waktu penggunaan layar), dan burnout_score (tingkat burnout). Warna pada heatmap menunjukkan seberapa kuat hubungan antar variabel: semakin terang warnanya, semakin kuat hubungannya. Dari grafik terlihat bahwa jam kerja memiliki hubungan yang sangat kuat dengan waktu penggunaan layar (nilai korelasi sekitar 0.95). Sementara itu, hubungan antara jam tidur dengan variabel lain terlihat sangat lemah atau hampir tidak ada.

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=burn_clean[['work_hours', 'sleep_hours', 'screen_time_hours', 'burnout_score']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi Jam Kerja, Tidur, dan Screentime terhadao Skor Burnout')
plt.show()

# %% [markdown]
# **Insight :**
#
#
# * Jam kerja memiliki hubungan yang sangat kuat dengan waktu penggunaan layar.
#
# * Jam tidur hampir tidak memiliki hubungan dengan jam kerja maupun screen time.
#
# * Skor burnout hanya memiliki hubungan yang lemah dengan jam kerja dan screen time.
#
#
# **Action :**
#
#
# * Melakukan analisis lebih lanjut untuk memahami mengapa jam kerja sangat berkaitan dengan screen time.
#
# * Menambahkan variabel lain (misalnya tingkat stres atau beban pekerjaan) untuk melihat faktor yang lebih memengaruhi burnout.

# %% [markdown]
# ## **Menyimpan Dataset Bersih**

# %%
burn_clean.to_csv('[CLEAN]WorkFromHomeEmployeeBurnout.csv', index=False)

# %%
burn_clean.to_excel('[CLEAN]WorkFromHomeEmployeeBurnout.xlsx', index=False)
